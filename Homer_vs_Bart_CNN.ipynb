# %%
# Instalação das bibliotecas necessárias
# !pip install streamlit opencv-python tensorflow numpy

# Importação das bibliotecas
import streamlit as st
import cv2
import numpy as np
from tensorflow.keras.models import load_model

# Carregando o modelo treinado
model = load_model('/Users/alansms/PycharmProjects/Fiap/MACHINE LEARNING/5ºCheckPoint_Redes_Neurais/Treino_modelo/modelo_personagens.h5')  # Ajuste o caminho conforme necessário

# Função para prever o personagem
def predict_character(image):
    img = cv2.resize(image, (64, 64))  # Redimensiona para o tamanho esperado
    img = np.expand_dims(img, axis=0) / 255.0  # Normaliza e adiciona dimensão
    prediction = model.predict(img)
    return np.argmax(prediction)

# Interface Streamlit
st.title("Classificador de Personagens")

# Seletor de personagens
characters = ['Homer', 'Bart', 'Lisa', 'Maggie']
selected_character = st.selectbox("Selecione um personagem", characters)

# Uploader de imagens
uploaded_file = st.file_uploader("Escolha uma imagem", type=["jpg", "jpeg", "png"])

if uploaded_file is not None:
    # Ler a imagem
    image = cv2.imdecode(np.frombuffer(uploaded_file.read(), np.uint8), cv2.IMREAD_COLOR)

    # Exibir a imagem
    st.image(image, channels="BGR", caption='Imagem carregada', use_column_width=True)

    # Prever o personagem
    prediction = predict_character(image)
    character_names = ['Homer', 'Bart', 'Lisa', 'Maggie']

    # Exibir o resultado
    st.write(f"O modelo previu: {character_names[prediction]}")

    if character_names[prediction] == selected_character:
        st.success("Você acertou!")
    else:
        st.error("Tente novamente!")
# Out:
# Requirement already satisfied: streamlit in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (1.39.0)
# Requirement already satisfied: opencv-python in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (4.10.0.84)
# Requirement already satisfied: tensorflow in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (2.16.2)
# Requirement already satisfied: numpy in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (1.26.4)
# Requirement already satisfied: altair<6,>=4.0 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from streamlit) (5.4.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from streamlit) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: packaging<25,>=20 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.4.0 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from streamlit) (4.25.5)
# Requirement already satisfied: pyarrow>=7.0 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from streamlit) (17.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from streamlit) (13.8.1)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: setuptools in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from tensorflow) (1.66.1)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: jinja2 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.5.2 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit) (1.9.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: namex in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from keras>=3.0.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from keras>=3.0.0->tensorflow) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from pandas<3,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.1.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.20.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.17,>=2.16->tensorflow) (8.5.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: zipp>=3.20 in /Users/alansms/PycharmProjects/FIAP/venv/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.17,>=2.16->tensorflow) (3.20.2)
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2024-11-08 11:39:18.061 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 11:39:18.062 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 11:39:18.062 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 11:39:18.062 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 11:39:18.062 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 11:39:18.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 11:39:18.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 11:39:18.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 11:39:18.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 11:39:18.064 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 11:39:18.064 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 11:39:18.064 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-08 11:39:18.064 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
